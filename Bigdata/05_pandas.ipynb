# %%
import pandas as pd
from pandas import Series, DataFrame

# series 설정
a = Series([1,3,5,7])
print(a)
print(a.values)
print(a.index)

#index 변경
a2 = pd.Series([1,3,5,7], index=['a','b','c','d'])
print(a2)
# Out:
# 0    1
# 1    3
# 2    5
# 3    7
# dtype: int64
# [1 3 5 7]
# RangeIndex(start=0, stop=4, step=1)
# a    1
# b    3
# c    5
# d    7
# dtype: int64

# %%
df = pd.read_csv('./practice/housing.csv', encoding='euc-kr')
df
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
# ...

# %%
df.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 0       322.0       126.0         8.3252            452600.0        NEAR BAY
# 1      2401.0      1138.0         8.3014            358500.0        NEAR BAY
# 2       496.0       177.0         7.2574            352100.0        NEAR BAY
# 3       558.0       219.0         5.6431            341300.0        NEAR BAY
# 4       565.0       259.0         3.8462            342200.0        NEAR BAY

# %%
df.tail()
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
#        population  households  median_income  median_house_value  \
# 20635       845.0       330.0         1.5603             78100.0
# 20636       356.0       114.0         2.5568             77100.0
# 20637      1007.0       433.0         1.7000             92300.0
# 20638       741.0       349.0         1.8672             84700.0
# 20639      1387.0       530.0         2.3886             89400.0
#
#       ocean_proximity
# 20635          INLAND
# 20636          INLAND
# 20637          INLAND
# 20638          INLAND
# ...

# %%
df[1:5]
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 1      2401.0      1138.0         8.3014            358500.0        NEAR BAY
# 2       496.0       177.0         7.2574            352100.0        NEAR BAY
# 3       558.0       219.0         5.6431            341300.0        NEAR BAY
# 4       565.0       259.0         3.8462            342200.0        NEAR BAY

# %%
df[:3]
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 0       322.0       126.0         8.3252            452600.0        NEAR BAY
# 1      2401.0      1138.0         8.3014            358500.0        NEAR BAY
# 2       496.0       177.0         7.2574            352100.0        NEAR BAY

# %%
df[60:]
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 60       -122.29     37.83                52.0       1121.0           211.0
# 61       -122.29     37.82                49.0        135.0            29.0
# 62       -122.29     37.81                50.0        760.0           190.0
# 63       -122.30     37.81                52.0       1224.0           237.0
# 64       -122.30     37.81                48.0        828.0           182.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
# ...

# %%
df['population'] #시리즈형태
# Out:
# 0         322.0
# 1        2401.0
# 2         496.0
# 3         558.0
# 4         565.0
#           ...
# 20635     845.0
# 20636     356.0
# 20637    1007.0
# 20638     741.0
# 20639    1387.0
# Name: population, Length: 20640, dtype: float64

# %%
df[['population']]
# Out:
#        population
# 0           322.0
# 1          2401.0
# 2           496.0
# 3           558.0
# 4           565.0
# ...           ...
# 20635       845.0
# 20636       356.0
# 20637      1007.0
# 20638       741.0
# 20639      1387.0
#
# [20640 rows x 1 columns]

# %%
df[df.columns[[0,2,4]]]
# Out:
#        longitude  housing_median_age  total_bedrooms
# 0        -122.23                41.0           129.0
# 1        -122.22                21.0          1106.0
# 2        -122.24                52.0           190.0
# 3        -122.25                52.0           235.0
# 4        -122.25                52.0           280.0
# ...          ...                 ...             ...
# 20635    -121.09                25.0           374.0
# 20636    -121.21                18.0           150.0
# 20637    -121.22                17.0           485.0
# 20638    -121.32                18.0           409.0
# 20639    -121.24                16.0           616.0
#
# [20640 rows x 3 columns]

# %%
df.loc[:,'housing_median_age':'total_bedrooms']
# Out:
#        housing_median_age  total_rooms  total_bedrooms
# 0                    41.0        880.0           129.0
# 1                    21.0       7099.0          1106.0
# 2                    52.0       1467.0           190.0
# 3                    52.0       1274.0           235.0
# 4                    52.0       1627.0           280.0
# ...                   ...          ...             ...
# 20635                25.0       1665.0           374.0
# 20636                18.0        697.0           150.0
# 20637                17.0       2254.0           485.0
# 20638                18.0       1860.0           409.0
# 20639                16.0       2785.0           616.0
#
# [20640 rows x 3 columns]

# %%
df.iloc[2:7,0:2]
# Out:
#    longitude  latitude
# 2    -122.24     37.85
# 3    -122.25     37.85
# 4    -122.25     37.85
# 5    -122.25     37.85
# 6    -122.25     37.84

# %%
df.at[5,'latitude']
# Out:
# 37.85

# %%
df_columns = df.copy()

# %%
df_columns.columns
# Out:
# Index(['longitude', 'latitude', 'housing_median_age', 'total_rooms',
#        'total_bedrooms', 'population', 'households', 'median_income',
#        'median_house_value', 'ocean_proximity'],
#       dtype='object')

# %%
df_columns = df_columns[['total_rooms','total_bedrooms']]
df_columns
# Out:
#        total_rooms  total_bedrooms
# 0            880.0           129.0
# 1           7099.0          1106.0
# 2           1467.0           190.0
# 3           1274.0           235.0
# 4           1627.0           280.0
# ...            ...             ...
# 20635       1665.0           374.0
# 20636        697.0           150.0
# 20637       2254.0           485.0
# 20638       1860.0           409.0
# 20639       2785.0           616.0
#
# [20640 rows x 2 columns]

# %%
df_columns.rename(columns={'total_rooms':'rooms','total_bedrooms':'bedrooms'},inplace=True)
df_columns
# Out:
#         rooms  bedrooms
# 0       880.0     129.0
# 1      7099.0    1106.0
# 2      1467.0     190.0
# 3      1274.0     235.0
# 4      1627.0     280.0
# ...       ...       ...
# 20635  1665.0     374.0
# 20636   697.0     150.0
# 20637  2254.0     485.0
# 20638  1860.0     409.0
# 20639  2785.0     616.0
#
# [20640 rows x 2 columns]

# %%
df_columns['avg'] = df_columns['rooms']/df_columns['bedrooms']
df_columns
# Out:
#         rooms  bedrooms       avg
# 0       880.0     129.0  6.821705
# 1      7099.0    1106.0  6.418626
# 2      1467.0     190.0  7.721053
# 3      1274.0     235.0  5.421277
# 4      1627.0     280.0  5.810714
# ...       ...       ...       ...
# 20635  1665.0     374.0  4.451872
# 20636   697.0     150.0  4.646667
# 20637  2254.0     485.0  4.647423
# 20638  1860.0     409.0  4.547677
# 20639  2785.0     616.0  4.521104
#
# [20640 rows x 3 columns]

# %%
del df_columns['avg']
df_columns
# Out:
#         rooms  bedrooms
# 0       880.0     129.0
# 1      7099.0    1106.0
# 2      1467.0     190.0
# 3      1274.0     235.0
# 4      1627.0     280.0
# ...       ...       ...
# 20635  1665.0     374.0
# 20636   697.0     150.0
# 20637  2254.0     485.0
# 20638  1860.0     409.0
# 20639  2785.0     616.0
#
# [20640 rows x 2 columns]

# %%
df.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 0       322.0       126.0         8.3252            452600.0        NEAR BAY
# 1      2401.0      1138.0         8.3014            358500.0        NEAR BAY
# 2       496.0       177.0         7.2574            352100.0        NEAR BAY
# 3       558.0       219.0         5.6431            341300.0        NEAR BAY
# 4       565.0       259.0         3.8462            342200.0        NEAR BAY

# %%
df_housing_old = df[(df['housing_median_age'] >= 50)]
df_housing_old
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# 5        -122.25     37.85                52.0        919.0           213.0
# 6        -122.25     37.84                52.0       2535.0           489.0
# ...          ...       ...                 ...          ...             ...
# 20235    -119.27     34.28                50.0       1710.0           412.0
# 20236    -119.27     34.27                52.0        459.0           112.0
# 20237    -119.27     34.27                52.0       1577.0           343.0
# 20443    -118.85     34.27                50.0        187.0            33.0
# 20592    -121.58     39.14                52.0        662.0           160.0
#
# ...

# %%
df['total_rooms'].value_counts()
# Out:
# 1527.0     18
# 1613.0     17
# 1582.0     17
# 2127.0     16
# 1717.0     15
#            ..
# 9614.0      1
# 10839.0     1
# 11872.0     1
# 6205.0      1
# 10035.0     1
# Name: total_rooms, Length: 5926, dtype: int64

# %%
def age_group(series):
    if series>=60:
        return 'X gen'
    elif series>= 30:
        return 'M gen'
    else:
        return 'Z gen'

df['generation'] = df['housing_median_age'].apply(age_group)
df.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income  median_house_value ocean_proximity  \
# 0       322.0       126.0         8.3252            452600.0        NEAR BAY
# 1      2401.0      1138.0         8.3014            358500.0        NEAR BAY
# 2       496.0       177.0         7.2574            352100.0        NEAR BAY
# 3       558.0       219.0         5.6431            341300.0        NEAR BAY
# 4       565.0       259.0         3.8462            342200.0        NEAR BAY
#
#   generation
# 0      M gen
# 1      Z gen
# 2      M gen
# ...

# %%
#pandas와 numpy 전환

import pandas as pd
df = pd.read_csv('./practice/housing.csv')
df.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 0       322.0       126.0         8.3252            452600.0        NEAR BAY
# 1      2401.0      1138.0         8.3014            358500.0        NEAR BAY
# 2       496.0       177.0         7.2574            352100.0        NEAR BAY
# 3       558.0       219.0         5.6431            341300.0        NEAR BAY
# 4       565.0       259.0         3.8462            342200.0        NEAR BAY

# %%
df_num = df.to_numpy()
df_num
# Out:
# array([[-122.23, 37.88, 41.0, ..., 8.3252, 452600.0, 'NEAR BAY'],
#        [-122.22, 37.86, 21.0, ..., 8.3014, 358500.0, 'NEAR BAY'],
#        [-122.24, 37.85, 52.0, ..., 7.2574, 352100.0, 'NEAR BAY'],
#        ...,
#        [-121.22, 39.43, 17.0, ..., 1.7, 92300.0, 'INLAND'],
#        [-121.32, 39.43, 18.0, ..., 1.8672, 84700.0, 'INLAND'],
#        [-121.24, 39.37, 16.0, ..., 2.3886, 89400.0, 'INLAND']],
#       dtype=object)

# %%
df_pd = pd.DataFrame(df_num)
df_pd
# Out:
#             0      1     2       3       4       5       6       7         8  \
# 0     -122.23  37.88  41.0   880.0   129.0   322.0   126.0  8.3252  452600.0
# 1     -122.22  37.86  21.0  7099.0  1106.0  2401.0  1138.0  8.3014  358500.0
# 2     -122.24  37.85  52.0  1467.0   190.0   496.0   177.0  7.2574  352100.0
# 3     -122.25  37.85  52.0  1274.0   235.0   558.0   219.0  5.6431  341300.0
# 4     -122.25  37.85  52.0  1627.0   280.0   565.0   259.0  3.8462  342200.0
# ...       ...    ...   ...     ...     ...     ...     ...     ...       ...
# 20635 -121.09  39.48  25.0  1665.0   374.0   845.0   330.0  1.5603   78100.0
# 20636 -121.21  39.49  18.0   697.0   150.0   356.0   114.0  2.5568   77100.0
# 20637 -121.22  39.43  17.0  2254.0   485.0  1007.0   433.0     1.7   92300.0
# 20638 -121.32  39.43  18.0  1860.0   409.0   741.0   349.0  1.8672   84700.0
# 20639 -121.24  39.37  16.0  2785.0   616.0  1387.0   530.0  2.3886   89400.0
#
#               9
# 0      NEAR BAY
# ...
