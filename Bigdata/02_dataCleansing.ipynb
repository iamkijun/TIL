# %%
# 단변량 데이터 검색 p75

import pandas as pd
data = pd.read_csv('./practice/iris_data.csv',encoding='utf-8')
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   sepal length (cm)  150 non-null    float64
#  1   sepal width (cm)   150 non-null    float64
#  2   petal length (cm)  150 non-null    float64
#  3   petal width (cm)   150 non-null    float64
#  4   target             150 non-null    int64
# dtypes: float64(4), int64(1)
# memory usage: 6.0 KB

# %%
data.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#    target
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0

# %%
data['target'].value_counts()
# Out:
# 0    50
# 1    50
# 2    50
# Name: target, dtype: int64

# %%
# %matplotlib inline
data['target'].value_counts().plot(kind="pie")
# Out:
# <AxesSubplot:ylabel='target'>

# %%
data['target'].value_counts().plot(kind="bar")
# Out:
# <AxesSubplot:>

# %%
data.describe()
# Out:
#        sepal length (cm)  sepal width (cm)  petal length (cm)  \
# count         150.000000        150.000000         150.000000
# mean            5.843333          3.057333           3.758000
# std             0.828066          0.435866           1.765298
# min             4.300000          2.000000           1.000000
# 25%             5.100000          2.800000           1.600000
# 50%             5.800000          3.000000           4.350000
# 75%             6.400000          3.300000           5.100000
# max             7.900000          4.400000           6.900000
#
#        petal width (cm)      target
# count        150.000000  150.000000
# mean           1.199333    1.000000
# std            0.762238    0.819232
# min            0.100000    0.000000
# 25%            0.300000    0.000000
# 50%            1.300000    1.000000
# 75%            1.800000    2.000000
# max            2.500000    2.000000

# %%
# 왜도(표본 비대칭도)
data.skew()
# Out:
# sepal length (cm)    0.314911
# sepal width (cm)     0.318966
# petal length (cm)   -0.274884
# petal width (cm)    -0.102967
# target               0.000000
# dtype: float64

# %%
# 첨도
data.kurtosis()
# Out:
# sepal length (cm)   -0.552064
# sepal width (cm)     0.228249
# petal length (cm)   -1.402103
# petal width (cm)    -1.340604
# target              -1.510135
# dtype: float64

# %%
import matplotlib.pyplot as plt
data.hist(bins=50, figsize=(20,15))
# Out:
# array([[<AxesSubplot:title={'center':'sepal length (cm)'}>,
#         <AxesSubplot:title={'center':'sepal width (cm)'}>],
#        [<AxesSubplot:title={'center':'petal length (cm)'}>,
#         <AxesSubplot:title={'center':'petal width (cm)'}>],
#        [<AxesSubplot:title={'center':'target'}>, <AxesSubplot:>]],
#       dtype=object)

# %%
data['sepal length (cm)'].hist(bins=50, figsize=(20,15))
# Out:
# <AxesSubplot:>

# %%
# 이변량 데이터 검색 p 82

data.corr()
# Out:
#                    sepal length (cm)  sepal width (cm)  petal length (cm)  \
# sepal length (cm)           1.000000         -0.117570           0.871754
# sepal width (cm)           -0.117570          1.000000          -0.428440
# petal length (cm)           0.871754         -0.428440           1.000000
# petal width (cm)            0.817941         -0.366126           0.962865
# target                      0.782561         -0.426658           0.949035
#
#                    petal width (cm)    target
# sepal length (cm)          0.817941  0.782561
# sepal width (cm)          -0.366126 -0.426658
# petal length (cm)          0.962865  0.949035
# petal width (cm)           1.000000  0.956547
# target                     0.956547  1.000000

# %%
data.corr(method='pearson')
# Out:
#                    sepal length (cm)  sepal width (cm)  petal length (cm)  \
# sepal length (cm)           1.000000         -0.117570           0.871754
# sepal width (cm)           -0.117570          1.000000          -0.428440
# petal length (cm)           0.871754         -0.428440           1.000000
# petal width (cm)            0.817941         -0.366126           0.962865
# target                      0.782561         -0.426658           0.949035
#
#                    petal width (cm)    target
# sepal length (cm)          0.817941  0.782561
# sepal width (cm)          -0.366126 -0.426658
# petal length (cm)          0.962865  0.949035
# petal width (cm)           1.000000  0.956547
# target                     0.956547  1.000000

# %%
data.corr(method='spearman')
# Out:
#                    sepal length (cm)  sepal width (cm)  petal length (cm)  \
# sepal length (cm)           1.000000         -0.166778           0.881898
# sepal width (cm)           -0.166778          1.000000          -0.309635
# petal length (cm)           0.881898         -0.309635           1.000000
# petal width (cm)            0.834289         -0.289032           0.937667
# target                      0.798078         -0.440290           0.935431
#
#                    petal width (cm)    target
# sepal length (cm)          0.834289  0.798078
# sepal width (cm)          -0.289032 -0.440290
# petal length (cm)          0.937667  0.935431
# petal width (cm)           1.000000  0.938179
# target                     0.938179  1.000000

# %%
data.corr(method='kendall')
# Out:
#                    sepal length (cm)  sepal width (cm)  petal length (cm)  \
# sepal length (cm)           1.000000         -0.076997           0.718516
# sepal width (cm)           -0.076997          1.000000          -0.185994
# petal length (cm)           0.718516         -0.185994           1.000000
# petal width (cm)            0.655309         -0.157126           0.806891
# target                      0.670444         -0.337614           0.822911
#
#                    petal width (cm)    target
# sepal length (cm)          0.655309  0.670444
# sepal width (cm)          -0.157126 -0.337614
# petal length (cm)          0.806891  0.822911
# petal width (cm)           1.000000  0.839687
# target                     0.839687  1.000000

# %%
import matplotlib.pyplot as plt
plt.scatter(data['sepal length (cm)'],data['petal length (cm)'],alpha=0.5)
plt.show()

# %%
plt.scatter(data['sepal width (cm)'],data['petal width (cm)'],alpha=0.5)
plt.show()

# %%
data.groupby('target')[['sepal width (cm)']].describe()
# Out:
#        sepal width (cm)
#                   count   mean       std  min    25%  50%    75%  max
# target
# 0                  50.0  3.428  0.379064  2.3  3.200  3.4  3.675  4.4
# 1                  50.0  2.770  0.313798  2.0  2.525  2.8  3.000  3.4
# 2                  50.0  2.974  0.322497  2.2  2.800  3.0  3.175  3.8

# %%
#이상치 처리

data.boxplot(column='sepal width (cm)', return_type='both')
# Out:
# BP(ax=<AxesSubplot:>, lines={'whiskers': [<matplotlib.lines.Line2D object at 0x7f7910137ac0>, <matplotlib.lines.Line2D object at 0x7f7910137e50>], 'caps': [<matplotlib.lines.Line2D object at 0x7f7910147190>, <matplotlib.lines.Line2D object at 0x7f7910147520>], 'boxes': [<matplotlib.lines.Line2D object at 0x7f7910137730>], 'medians': [<matplotlib.lines.Line2D object at 0x7f79101478b0>], 'fliers': [<matplotlib.lines.Line2D object at 0x7f7910147c70>], 'means': []})

# %%
data.boxplot(column='sepal length (cm)', return_type='both')
# Out:
# BP(ax=<AxesSubplot:>, lines={'whiskers': [<matplotlib.lines.Line2D object at 0x7f7921e02430>, <matplotlib.lines.Line2D object at 0x7f7921e1e430>], 'caps': [<matplotlib.lines.Line2D object at 0x7f7921e1e190>, <matplotlib.lines.Line2D object at 0x7f7921e1ea90>], 'boxes': [<matplotlib.lines.Line2D object at 0x7f7921e02820>], 'medians': [<matplotlib.lines.Line2D object at 0x7f7921e1e4f0>], 'fliers': [<matplotlib.lines.Line2D object at 0x7f7921e1eca0>], 'means': []})

# %%
Q1_sepal_length = data['sepal length (cm)'].quantile(q=0.25)
Q3_sepal_length = data['sepal length (cm)'].quantile(q=0.75)
IQR_sepal_length = Q3_sepal_length - Q1_sepal_length
IQR_sepal_length
# Out:
# 1.3000000000000007

# %%
data_IQR = data[(data['sepal length (cm)'] < Q3_sepal_length + IQR_sepal_length*1.5) & (data['sepal length (cm)']>Q1_sepal_length-IQR_sepal_length*1.5)]
data_IQR['sepal length (cm)'].hist()
# Out:
# <AxesSubplot:>

# %%
data_IQR.hist(bins=50, figsize=(20,15))
# Out:
# array([[<AxesSubplot:title={'center':'sepal length (cm)'}>,
#         <AxesSubplot:title={'center':'sepal width (cm)'}>],
#        [<AxesSubplot:title={'center':'petal length (cm)'}>,
#         <AxesSubplot:title={'center':'petal width (cm)'}>],
#        [<AxesSubplot:title={'center':'target'}>, <AxesSubplot:>]],
#       dtype=object)

# %%
data_IQR.corr()
# Out:
#                    sepal length (cm)  sepal width (cm)  petal length (cm)  \
# sepal length (cm)           1.000000         -0.117570           0.871754
# sepal width (cm)           -0.117570          1.000000          -0.428440
# petal length (cm)           0.871754         -0.428440           1.000000
# petal width (cm)            0.817941         -0.366126           0.962865
# target                      0.782561         -0.426658           0.949035
#
#                    petal width (cm)    target
# sepal length (cm)          0.817941  0.782561
# sepal width (cm)          -0.366126 -0.426658
# petal length (cm)          0.962865  0.949035
# petal width (cm)           1.000000  0.956547
# target                     0.956547  1.000000

# %%
import matplotlib.pyplot as plt
plt.scatter(data_IQR['sepal length (cm)'],data_IQR['petal length (cm)'], alpha=0.5)
plt.show()

# %%
# 변수 변환
import numpy as np
data['log_sepal length (cm)'] = np.log(data['sepal length (cm)'])
data['log_petal length (cm)'] = np.log(data['petal length (cm)'])
data.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#    target  log_sepal length (cm)  log_petal length (cm)
# 0       0               1.629241               0.336472
# 1       0               1.589235               0.336472
# 2       0               1.547563               0.262364
# 3       0               1.526056               0.405465
# 4       0               1.609438               0.336472

# %%
data.hist(bins=50, figsize=(20,15))
# Out:
# array([[<AxesSubplot:title={'center':'sepal length (cm)'}>,
#         <AxesSubplot:title={'center':'sepal width (cm)'}>,
#         <AxesSubplot:title={'center':'petal length (cm)'}>],
#        [<AxesSubplot:title={'center':'petal width (cm)'}>,
#         <AxesSubplot:title={'center':'target'}>,
#         <AxesSubplot:title={'center':'log_sepal length (cm)'}>],
#        [<AxesSubplot:title={'center':'log_petal length (cm)'}>,
#         <AxesSubplot:>, <AxesSubplot:>]], dtype=object)

# %%
data.corr()
# Out:
#                        sepal length (cm)  sepal width (cm)  petal length (cm)  \
# sepal length (cm)               1.000000         -0.117570           0.871754
# sepal width (cm)               -0.117570          1.000000          -0.428440
# petal length (cm)               0.871754         -0.428440           1.000000
# petal width (cm)                0.817941         -0.366126           0.962865
# target                          0.782561         -0.426658           0.949035
# log_sepal length (cm)           0.996880         -0.127834           0.878635
# log_petal length (cm)           0.826019         -0.493757           0.986205
#
#                        petal width (cm)    target  log_sepal length (cm)  \
# sepal length (cm)              0.817941  0.782561               0.996880
# sepal width (cm)              -0.366126 -0.426658              -0.127834
# petal length (cm)              0.962865  0.949035               0.878635
# ...

# %%
data['sqrt_sepal length (cm)'] = np.sqrt(data['sepal length (cm)'])
data['sqrt_petal length (cm)'] = np.sqrt(data['petal length (cm)'])
data.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#    target  log_sepal length (cm)  log_petal length (cm)  \
# 0       0               1.629241               0.336472
# 1       0               1.589235               0.336472
# 2       0               1.547563               0.262364
# 3       0               1.526056               0.405465
# 4       0               1.609438               0.336472
#
#    sqrt_sepal length (cm)  sqrt_petal length (cm)
# 0                2.258318                1.183216
# 1                2.213594                1.183216
# ...

# %%
data.hist(bins=50, figsize=(20,15))
data.corr()
# Out:
#                         sepal length (cm)  sepal width (cm)  \
# sepal length (cm)                1.000000         -0.117570
# sepal width (cm)                -0.117570          1.000000
# petal length (cm)                0.871754         -0.428440
# petal width (cm)                 0.817941         -0.366126
# target                           0.782561         -0.426658
# log_sepal length (cm)            0.996880         -0.127834
# log_petal length (cm)            0.826019         -0.493757
# sqrt_sepal length (cm)           0.999215         -0.123032
# sqrt_petal length (cm)           0.850360         -0.464867
#
#                         petal length (cm)  petal width (cm)    target  \
# sepal length (cm)                0.871754          0.817941  0.782561
# sepal width (cm)                -0.428440         -0.366126 -0.426658
# petal length (cm)                1.000000          0.962865  0.949035
# petal width (cm)                 0.962865          1.000000  0.956547
# ...

# %%
#결측치 처리 p98
import pandas as pd
data = pd.read_csv('./practice/housing.csv')
data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
# ...

# %%
pd.isnull(data)
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0          False     False               False        False           False
# 1          False     False               False        False           False
# 2          False     False               False        False           False
# 3          False     False               False        False           False
# 4          False     False               False        False           False
# ...          ...       ...                 ...          ...             ...
# 20635      False     False               False        False           False
# 20636      False     False               False        False           False
# 20637      False     False               False        False           False
# 20638      False     False               False        False           False
# 20639      False     False               False        False           False
#
# ...

# %%
data.isnull()
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0          False     False               False        False           False
# 1          False     False               False        False           False
# 2          False     False               False        False           False
# 3          False     False               False        False           False
# 4          False     False               False        False           False
# ...          ...       ...                 ...          ...             ...
# 20635      False     False               False        False           False
# 20636      False     False               False        False           False
# 20637      False     False               False        False           False
# 20638      False     False               False        False           False
# 20639      False     False               False        False           False
#
# ...

# %%
pd.notnull(data)
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0           True      True                True         True            True
# 1           True      True                True         True            True
# 2           True      True                True         True            True
# 3           True      True                True         True            True
# 4           True      True                True         True            True
# ...          ...       ...                 ...          ...             ...
# 20635       True      True                True         True            True
# 20636       True      True                True         True            True
# 20637       True      True                True         True            True
# 20638       True      True                True         True            True
# 20639       True      True                True         True            True
#
# ...

# %%
data.notnull()
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0           True      True                True         True            True
# 1           True      True                True         True            True
# 2           True      True                True         True            True
# 3           True      True                True         True            True
# 4           True      True                True         True            True
# ...          ...       ...                 ...          ...             ...
# 20635       True      True                True         True            True
# 20636       True      True                True         True            True
# 20637       True      True                True         True            True
# 20638       True      True                True         True            True
# 20639       True      True                True         True            True
#
# ...

# %%
data.isnull().sum()
# Out:
# longitude               0
# latitude                0
# housing_median_age      0
# total_rooms             0
# total_bedrooms        207
# population              0
# households              0
# median_income           0
# median_house_value      0
# ocean_proximity         0
# dtype: int64

# %%
data['total_bedrooms'].isnull().sum()
# Out:
# 207

# %%
data['total_bedrooms'].notnull().sum()
# Out:
# 20433

# %%
data.isnull().sum(1)
# Out:
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
#         ..
# 20635    0
# 20636    0
# 20637    0
# 20638    0
# 20639    0
# Length: 20640, dtype: int64

# %%
data['missing'] = data.isnull().sum(1)
data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
# ...

# %%
del data['missing']
data['valid'] = data.notnull().sum(1)
data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
# ...

# %%
# 결측값 제거
data_del_row = data.dropna(axis = 0)
data_del_row
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
# ...

# %%
data_del_col = data.dropna(axis=1)
data_del_col
# Out:
#        longitude  latitude  housing_median_age  total_rooms  population  \
# 0        -122.23     37.88                41.0        880.0       322.0
# 1        -122.22     37.86                21.0       7099.0      2401.0
# 2        -122.24     37.85                52.0       1467.0       496.0
# 3        -122.25     37.85                52.0       1274.0       558.0
# 4        -122.25     37.85                52.0       1627.0       565.0
# ...          ...       ...                 ...          ...         ...
# 20635    -121.09     39.48                25.0       1665.0       845.0
# 20636    -121.21     39.49                18.0        697.0       356.0
# 20637    -121.22     39.43                17.0       2254.0      1007.0
# 20638    -121.32     39.43                18.0       1860.0       741.0
# 20639    -121.24     39.37                16.0       2785.0      1387.0
#
#        households  median_income  median_house_value ocean_proximity  valid
# ...

# %%
data[['total_bedrooms']].dropna()
# Out:
#        total_bedrooms
# 0               129.0
# 1              1106.0
# 2               190.0
# 3               235.0
# 4               280.0
# ...               ...
# 20635           374.0
# 20636           150.0
# 20637           485.0
# 20638           409.0
# 20639           616.0
#
# [20433 rows x 1 columns]

# %%
# 결측값 대체


import pandas as pd
data = pd.read_csv('./practice/housing.csv')
data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
# ...

# %%
#결측값을 대체하는 방법
#1. 특정값으로 대체 - replace mssing values with scalar value
#2. 변수별 평균으로 대체: filling missing values with mean value per columns
#3. 다른 변수의 값으로 대체: filling mssing values with another columns values
#4. 그룹 평균값으로 대체: fill missing values by Group means

# %%
# 결측값을 0으로 대체
data_0 =data.fillna(0)
data_0.head(292)
# Out:
#      longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0      -122.23     37.88                41.0        880.0           129.0
# 1      -122.22     37.86                21.0       7099.0          1106.0
# 2      -122.24     37.85                52.0       1467.0           190.0
# 3      -122.25     37.85                52.0       1274.0           235.0
# 4      -122.25     37.85                52.0       1627.0           280.0
# ..         ...       ...                 ...          ...             ...
# 287    -122.18     37.78                50.0       1642.0           322.0
# 288    -122.17     37.78                49.0        893.0           177.0
# 289    -122.17     37.78                52.0        653.0           128.0
# 290    -122.16     37.77                47.0       1256.0             0.0
# 291    -122.16     37.77                48.0        977.0           194.0
#
#      population  households  median_income  median_house_value ocean_proximity
# ...

# %%
# 결측값을 특정 값으로 대체
data_missing = data.fillna('missing')
data_missing.head(292)
# Out:
#      longitude  latitude  housing_median_age  total_rooms total_bedrooms  \
# 0      -122.23     37.88                41.0        880.0          129.0
# 1      -122.22     37.86                21.0       7099.0         1106.0
# 2      -122.24     37.85                52.0       1467.0          190.0
# 3      -122.25     37.85                52.0       1274.0          235.0
# 4      -122.25     37.85                52.0       1627.0          280.0
# ..         ...       ...                 ...          ...            ...
# 287    -122.18     37.78                50.0       1642.0          322.0
# 288    -122.17     37.78                49.0        893.0          177.0
# 289    -122.17     37.78                52.0        653.0          128.0
# 290    -122.16     37.77                47.0       1256.0        missing
# 291    -122.16     37.77                48.0        977.0          194.0
#
#      population  households  median_income  median_house_value ocean_proximity
# ...

# %%
#결측값을 앞 방향으로 채우는 방법
#이전 변수값을 그대로 갖다 쓴다.

data_ffill = data.fillna(method='ffill')
data_ffill.head(292)
# Out:
#      longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0      -122.23     37.88                41.0        880.0           129.0
# 1      -122.22     37.86                21.0       7099.0          1106.0
# 2      -122.24     37.85                52.0       1467.0           190.0
# 3      -122.25     37.85                52.0       1274.0           235.0
# 4      -122.25     37.85                52.0       1627.0           280.0
# ..         ...       ...                 ...          ...             ...
# 287    -122.18     37.78                50.0       1642.0           322.0
# 288    -122.17     37.78                49.0        893.0           177.0
# 289    -122.17     37.78                52.0        653.0           128.0
# 290    -122.16     37.77                47.0       1256.0           128.0
# 291    -122.16     37.77                48.0        977.0           194.0
#
#      population  households  median_income  median_house_value ocean_proximity
# ...

# %%
#결측값을 앞 방향으로 채우는 방법
#이전 변수값을 그대로 갖다 쓴다.

data_pad = data.fillna(method='pad')
data_pad.head(292)
# Out:
#      longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0      -122.23     37.88                41.0        880.0           129.0
# 1      -122.22     37.86                21.0       7099.0          1106.0
# 2      -122.24     37.85                52.0       1467.0           190.0
# 3      -122.25     37.85                52.0       1274.0           235.0
# 4      -122.25     37.85                52.0       1627.0           280.0
# ..         ...       ...                 ...          ...             ...
# 287    -122.18     37.78                50.0       1642.0           322.0
# 288    -122.17     37.78                49.0        893.0           177.0
# 289    -122.17     37.78                52.0        653.0           128.0
# 290    -122.16     37.77                47.0       1256.0           128.0
# 291    -122.16     37.77                48.0        977.0           194.0
#
#      population  households  median_income  median_house_value ocean_proximity
# ...

# %%
#결측값을 뒤 방향으로 채우는 방법
#다음 변수값을 그대로 갖다 쓴다.

data_bfill = data.fillna(method='bfill')
data_bfill.head(292)
# Out:
#      longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0      -122.23     37.88                41.0        880.0           129.0
# 1      -122.22     37.86                21.0       7099.0          1106.0
# 2      -122.24     37.85                52.0       1467.0           190.0
# 3      -122.25     37.85                52.0       1274.0           235.0
# 4      -122.25     37.85                52.0       1627.0           280.0
# ..         ...       ...                 ...          ...             ...
# 287    -122.18     37.78                50.0       1642.0           322.0
# 288    -122.17     37.78                49.0        893.0           177.0
# 289    -122.17     37.78                52.0        653.0           128.0
# 290    -122.16     37.77                47.0       1256.0           194.0
# 291    -122.16     37.77                48.0        977.0           194.0
#
#      population  households  median_income  median_house_value ocean_proximity
# ...

# %%
#결측값을 뒤 방향으로 채우는 방법
#다음 변수값을 그대로 갖다 쓴다.

data_backfill = data.fillna(method='backfill')
data_backfill.head(292)
# Out:
#      longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0      -122.23     37.88                41.0        880.0           129.0
# 1      -122.22     37.86                21.0       7099.0          1106.0
# 2      -122.24     37.85                52.0       1467.0           190.0
# 3      -122.25     37.85                52.0       1274.0           235.0
# 4      -122.25     37.85                52.0       1627.0           280.0
# ..         ...       ...                 ...          ...             ...
# 287    -122.18     37.78                50.0       1642.0           322.0
# 288    -122.17     37.78                49.0        893.0           177.0
# 289    -122.17     37.78                52.0        653.0           128.0
# 290    -122.16     37.77                47.0       1256.0           194.0
# 291    -122.16     37.77                48.0        977.0           194.0
#
#      population  households  median_income  median_house_value ocean_proximity
# ...

# %%
# 평균대체

data_mean = data.fillna(data.mean())
data_mean.head(292)
# Out:
# C:\Users\multicampus\AppData\Local\Temp\ipykernel_8124\762545201.py:3: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data_mean = data.fillna(data.mean())
#      longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0      -122.23     37.88                41.0        880.0      129.000000
# 1      -122.22     37.86                21.0       7099.0     1106.000000
# 2      -122.24     37.85                52.0       1467.0      190.000000
# 3      -122.25     37.85                52.0       1274.0      235.000000
# 4      -122.25     37.85                52.0       1627.0      280.000000
# ..         ...       ...                 ...          ...             ...
# ...

# %%
# 평균대체

data_mean = data.fillna(data['total_bedrooms'].mean())
data_mean.head(292)
# Out:
#      longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0      -122.23     37.88                41.0        880.0      129.000000
# 1      -122.22     37.86                21.0       7099.0     1106.000000
# 2      -122.24     37.85                52.0       1467.0      190.000000
# 3      -122.25     37.85                52.0       1274.0      235.000000
# 4      -122.25     37.85                52.0       1627.0      280.000000
# ..         ...       ...                 ...          ...             ...
# 287    -122.18     37.78                50.0       1642.0      322.000000
# 288    -122.17     37.78                49.0        893.0      177.000000
# 289    -122.17     37.78                52.0        653.0      128.000000
# 290    -122.16     37.77                47.0       1256.0      537.870553
# 291    -122.16     37.77                48.0        977.0      194.000000
#
#      population  households  median_income  median_house_value ocean_proximity
# ...

# %%
# 중위수대체

data_median = data.fillna(data['total_bedrooms'].median())
data_median.head(292)
# Out:
#      longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0      -122.23     37.88                41.0        880.0           129.0
# 1      -122.22     37.86                21.0       7099.0          1106.0
# 2      -122.24     37.85                52.0       1467.0           190.0
# 3      -122.25     37.85                52.0       1274.0           235.0
# 4      -122.25     37.85                52.0       1627.0           280.0
# ..         ...       ...                 ...          ...             ...
# 287    -122.18     37.78                50.0       1642.0           322.0
# 288    -122.17     37.78                49.0        893.0           177.0
# 289    -122.17     37.78                52.0        653.0           128.0
# 290    -122.16     37.77                47.0       1256.0           435.0
# 291    -122.16     37.77                48.0        977.0           194.0
#
#      population  households  median_income  median_house_value ocean_proximity
# ...

# %%
# 최소값대체

data_min = data.fillna(data.min())
data_min.head(292)
# Out:
#      longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0      -122.23     37.88                41.0        880.0           129.0
# 1      -122.22     37.86                21.0       7099.0          1106.0
# 2      -122.24     37.85                52.0       1467.0           190.0
# 3      -122.25     37.85                52.0       1274.0           235.0
# 4      -122.25     37.85                52.0       1627.0           280.0
# ..         ...       ...                 ...          ...             ...
# 287    -122.18     37.78                50.0       1642.0           322.0
# 288    -122.17     37.78                49.0        893.0           177.0
# 289    -122.17     37.78                52.0        653.0           128.0
# 290    -122.16     37.77                47.0       1256.0             1.0
# 291    -122.16     37.77                48.0        977.0           194.0
#
#      population  households  median_income  median_house_value ocean_proximity
# ...

# %%
# 최대값대체

data_max = data.fillna(data.max())
data_max.head(292)
# Out:
#      longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0      -122.23     37.88                41.0        880.0           129.0
# 1      -122.22     37.86                21.0       7099.0          1106.0
# 2      -122.24     37.85                52.0       1467.0           190.0
# 3      -122.25     37.85                52.0       1274.0           235.0
# 4      -122.25     37.85                52.0       1627.0           280.0
# ..         ...       ...                 ...          ...             ...
# 287    -122.18     37.78                50.0       1642.0           322.0
# 288    -122.17     37.78                49.0        893.0           177.0
# 289    -122.17     37.78                52.0        653.0           128.0
# 290    -122.16     37.77                47.0       1256.0          6445.0
# 291    -122.16     37.77                48.0        977.0           194.0
#
#      population  households  median_income  median_house_value ocean_proximity
# ...

# %%
# 다른 컬럼의 변수 참고

data_other_mean = data.fillna(data.mean()['total_rooms'])
data_other_mean.head(292)
# Out:
# C:\Users\multicampus\AppData\Local\Temp\ipykernel_8124\4086861949.py:3: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data_other_mean = data.fillna(data.mean()['total_rooms'])
#      longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0      -122.23     37.88                41.0        880.0      129.000000
# 1      -122.22     37.86                21.0       7099.0     1106.000000
# 2      -122.24     37.85                52.0       1467.0      190.000000
# 3      -122.25     37.85                52.0       1274.0      235.000000
# 4      -122.25     37.85                52.0       1627.0      280.000000
# ..         ...       ...                 ...          ...             ...
# ...

# %%
#다른 변수 값으로 대체 ( total_bedrooms가 null값이라면, total_rooms값으로 대체)

import numpy as np

data2 = data.copy()
data2['total_bedrooms_new'] = np.where(pd.notnull(data2['total_bedrooms']) == True,
                                      data2['total_bedrooms'],data2['total_rooms'])
data2.head(292)
# Out:
#      longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0      -122.23     37.88                41.0        880.0           129.0
# 1      -122.22     37.86                21.0       7099.0          1106.0
# 2      -122.24     37.85                52.0       1467.0           190.0
# 3      -122.25     37.85                52.0       1274.0           235.0
# 4      -122.25     37.85                52.0       1627.0           280.0
# ..         ...       ...                 ...          ...             ...
# 287    -122.18     37.78                50.0       1642.0           322.0
# 288    -122.17     37.78                49.0        893.0           177.0
# 289    -122.17     37.78                52.0        653.0           128.0
# 290    -122.16     37.77                47.0       1256.0             NaN
# 291    -122.16     37.77                48.0        977.0           194.0
#
#      population  households  median_income  median_house_value  \
# ...

# %%
#집단 평균값으로 대체

data.groupby('housing_median_age').mean()
# Out:
# C:\Users\multicampus\AppData\Local\Temp\ipykernel_8124\995670129.py:3: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   data.groupby('housing_median_age').mean()
#                      longitude   latitude  total_rooms  total_bedrooms  \
# housing_median_age
# 1.0                -119.457500  36.205000  1101.250000      172.000000
# 2.0                -119.121379  35.494483  5530.293103      913.758621
# 3.0                -118.936452  35.284516  7160.080645     1233.419355
# 4.0                -118.814293  34.966963  6237.282723     1113.042105
# 5.0                -118.918033  35.234262  5018.307377      935.814050
# 6.0                -118.994313  35.233125  4541.406250      864.006369
# 7.0                -119.111486  35.544286  5430.720000      994.398844
# ...

# %%
fill_mean_func = lambda g: g.fillna(g.mean())

# %%
data_group_mean = data.groupby('housing_median_age').apply(fill_mean_func)
data_group_mean.head(292)
# Out:
# C:\Users\multicampus\AppData\Local\Temp\ipykernel_8124\4294930418.py:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   fill_mean_func = lambda g: g.fillna(g.mean())
# C:\Users\multicampus\AppData\Local\Temp\ipykernel_8124\1692734676.py:1: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   data_group_mean = data.groupby('housing_median_age').apply(fill_mean_func)
# ...

# %%
fill_values = {47.0 : 147}

# %%
fill_func = lambda b: b.fillna(fill_values)

# %%
data_group_value = data.groupby('housing_median_age').apply(fill_func)
# Out:
# C:\Users\multicampus\AppData\Local\Temp\ipykernel_8124\2873436427.py:1: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   data_group_value = data.groupby('housing_median_age').apply(fill_func)

# %%
data_group_value.head(292)
# Out:
#      longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0      -122.23     37.88                41.0        880.0           129.0
# 1      -122.22     37.86                21.0       7099.0          1106.0
# 2      -122.24     37.85                52.0       1467.0           190.0
# 3      -122.25     37.85                52.0       1274.0           235.0
# 4      -122.25     37.85                52.0       1627.0           280.0
# ..         ...       ...                 ...          ...             ...
# 287    -122.18     37.78                50.0       1642.0           322.0
# 288    -122.17     37.78                49.0        893.0           177.0
# 289    -122.17     37.78                52.0        653.0           128.0
# 290    -122.16     37.77                47.0       1256.0             NaN
# 291    -122.16     37.77                48.0        977.0           194.0
#
#      population  households  median_income  median_house_value ocean_proximity
# ...
